# %%
#!/usr/bin/env python

import tensorflow as tf
import numpy as np
import input_data


def init_weights(shape, name):
    return tf.Variable(tf.random_normal(shape, stddev=0.01), name=name)

# This network is the same as the previous one except with an extra hidden layer + dropout
def model(X, w_h, w_h2, w_o, p_keep_input, p_keep_hidden):
    # Add layer name scopes for better graph visualization
    with tf.name_scope("layer1") as scope:
        X = tf.nn.dropout(X, p_keep_input)
        h = tf.nn.relu(tf.matmul(X, w_h))
    with tf.name_scope("layer2") as scope:
        h = tf.nn.dropout(h, p_keep_hidden)
        h2 = tf.nn.relu(tf.matmul(h, w_h2))
    with tf.name_scope("layer3") as scope:
        h2 = tf.nn.dropout(h2, p_keep_hidden)
        return tf.matmul(h2, w_o)

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
trX, trY, teX, teY = mnist.train.images, mnist.train.labels, mnist.test.images, mnist.test.labels

X = tf.placeholder("float", [None, 784], name="X")
Y = tf.placeholder("float", [None, 10], name="Y")

w_h = init_weights([784, 625], "w_h")
w_h2 = init_weights([625, 625], "w_h2")
w_o = init_weights([625, 10], "w_o")

# Add histogram summaries for weights
tf.histogram_summary("w_h_summ", w_h)
tf.histogram_summary("w_h2_summ", w_h2)
tf.histogram_summary("w_o_summ", w_o)

p_keep_input = tf.placeholder("float", name="p_keep_input")
p_keep_hidden = tf.placeholder("float", name="p_keep_hidden")
py_x = model(X, w_h, w_h2, w_o, p_keep_input, p_keep_hidden)

with tf.name_scope("cost") as scope:
    cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(py_x, Y))
    train_op = tf.train.RMSPropOptimizer(0.001, 0.9).minimize(cost)
    # Add scalar summary for cost
    tf.scalar_summary("cost", cost)

with tf.name_scope("accuracy") as scope:
    correct_pred = tf.equal(tf.argmax(Y, 1), tf.argmax(py_x, 1)) # Count correct predictions
    acc_op = tf.reduce_mean(tf.cast(correct_pred, "float")) # Cast boolean to float to average
    # Add scalar summary for accuracy
    tf.scalar_summary("accuracy", acc_op)

with tf.Session() as sess:
    # create a log writer. run 'tensorboard --logdir=./logs/nn_logs'
    writer = tf.train.SummaryWriter("./logs/nn_logs", sess.graph)
    merged = tf.merge_all_summaries()

    # you need to initialize all variables
    tf.initialize_all_variables().run()

    for i in range(10):
        for start, end in zip(range(0, len(trX), 128), range(128, len(trX), 128)):
            sess.run(train_op, feed_dict={X: trX[start:end], Y: trY[start:end],
                                          p_keep_input: 0.8, p_keep_hidden: 0.5})
        summary, acc = sess.run([merged, acc_op], feed_dict={X: teX, Y: teY,
                                          p_keep_input: 1.0, p_keep_hidden: 1.0})
        writer.add_summary(summary, i)  # Write summary
        print(i, acc)                   # Report the accuracy
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# /Users/act65/anaconda/lib/python3.5/gzip.py:274: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   return self._buffer.read(size)
# /Users/act65/Documents/Jupyter/Tensorflow/input_data.py:38: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   data = data.reshape(num_images, rows, cols, 1)
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# 0 0.9352
# 1 0.9617
# 2 0.9721
# 3 0.9747
# 4 0.9717
# 5 0.9764
# 6 0.9772
# 7 0.977
# 8 0.9762
# 9 0.9792

# %%
# !tensorboard --logdir=./logs/nn_logs
# Out:
# WARNING:tensorflow:Found more than one graph event per run. Overwriting the graph with the newest event.
# WARNING:tensorflow:Found more than one graph event per run. Overwriting the graph with the newest event.
# WARNING:tensorflow:Found more than one graph event per run. Overwriting the graph with the newest event.
# WARNING:tensorflow:Found more than one graph event per run. Overwriting the graph with the newest event.
# WARNING:tensorflow:Found more than one graph event per run. Overwriting the graph with the newest event.
# WARNING:tensorflow:Found more than one graph event per run. Overwriting the graph with the newest event.
# WARNING:tensorflow:IOError [Errno 2] No such file or directory: '/Users/act65/anaconda/lib/python3.5/site-packages/tensorflow/tensorboard/TAG' on path /Users/act65/anaconda/lib/python3.5/site-packages/tensorflow/tensorboard/TAG
# WARNING:tensorflow:Unable to read TensorBoard tag
# Starting TensorBoard  on port 6006
# (You can navigate to http://0.0.0.0:6006)
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET / HTTP/1.1" 200 -
# WARNING:tensorflow:IOError [Errno 2] No such file or directory: '/Users/act65/anaconda/lib/python3.5/site-packages/tensorflow/tensorboard/lib/css/global.css' on path /Users/act65/anaconda/lib/python3.5/site-packages/tensorflow/tensorboard/lib/css/global.css
# 127.0.0.1 - - [18/Apr/2016 10:58:07] code 404, message Not Found
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /lib/css/global.css HTTP/1.1" 404 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/lodash/lodash.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/d3/d3.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/graphlib/dist/graphlib.core.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/plottable/plottable.css HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/plottable/plottable.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/dagre/dist/dagre.core.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/polymer/polymer.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/webcomponentsjs/webcomponents-lite.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/iron-ajax/iron-ajax.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/iron-collapse/iron-collapse.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/iron-list/iron-list.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-button/paper-button.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-checkbox/paper-checkbox.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-dropdown-menu/paper-dropdown-menu.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-header-panel/paper-header-panel.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-icon-button/paper-icon-button.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-input/paper-input.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-item/paper-item.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-menu/paper-menu.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-radio-button/paper-radio-button.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-progress/paper-progress.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-radio-group/paper-radio-group.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-styles/paper-styles.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-toggle-button/paper-toggle-button.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-toolbar/paper-toolbar.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-tabs/paper-tabs.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /dist/tf-tensorboard.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/paper-slider/paper-slider.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/polymer/polymer-mini.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:07] "GET /external/polymer/polymer-micro.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-behaviors/paper-checked-element-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-flex-layout/iron-flex-layout.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-range-behavior/iron-range-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-styles/default-theme.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-styles/color.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-item/paper-item-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-item/paper-item-shared-styles.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-input/iron-input.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-form-element-behavior/iron-form-element-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-input/paper-input-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-input/paper-input-char-counter.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-input/paper-input-container.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-behaviors/paper-inky-focus-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-input/paper-input-error.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-a11y-keys-behavior/iron-a11y-keys-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-ripple/paper-ripple.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-menu/paper-menu-shared-styles.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-menu-behavior/iron-menu-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-styles/typography.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-flex-layout/classes/iron-flex-layout.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-styles/shadow.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-material/paper-material.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-behaviors/paper-button-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-icon/iron-icon.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-menu-behavior/iron-menubar-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-tabs/paper-tabs-icons.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-resizable-behavior/iron-resizable-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-tabs/paper-tab.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-selector/iron-selectable.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-menu-button/paper-menu-button.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-behaviors/iron-control-state.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-icons/iron-icons.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-behaviors/iron-button-state.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-validatable-behavior/iron-validatable-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-ajax/iron-request.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-checked-element-behavior/iron-checked-element-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-a11y-announcer/iron-a11y-announcer.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-input/paper-input-addon-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-behaviors/paper-ripple-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-selector/iron-multi-selectable.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/font-roboto/roboto.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-flex-layout/classes/iron-shadow-flex-layout.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-material/paper-material-shared-styles.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-meta/iron-meta.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-iconset-svg/iron-iconset-svg.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-dropdown/iron-dropdown.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-selector/iron-selection.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/animations/fade-in-animation.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/animations/fade-out-animation.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/paper-menu-button/paper-menu-button-animations.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/promise-polyfill/promise-polyfill-lite.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-overlay-behavior/iron-overlay-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/animations/opaque-animation.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/neon-animation-runner-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-dropdown/iron-dropdown-scroll-manager.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/neon-animation-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/web-animations.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/promise-polyfill/Promise.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-fit-behavior/iron-fit-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-overlay-behavior/iron-overlay-manager.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/iron-overlay-behavior/iron-overlay-backdrop.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/neon-animation/neon-animatable-behavior.html HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /external/web-animations-js/web-animations-next-lite.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Apr/2016 10:58:08] "GET /data/runs HTTP/1.1" 200 -
