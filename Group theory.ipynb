# %% [markdown]
# ### Definitions
#
# * A set of example definitions for the set [a,b,c] with the + opperator
#     * Associative: $(a + b) + c = a + (b + c)$
#     * Closure $\forall a,b \in \mathbb{G} \; \exists \; c \in \mathbb{G} :  a + b = c $
#     * Identity $a + I = a$
#     * Inverse $inv(a) + a = I$
#
# * Distributive
# * Commutative: $ a + b = b + a $
#
# So by definition, if there is an inverse there is an identity? Or vice versa?
#
# * A group
# * A ring
# * A field
#
# ### Motivation
#
# Why is this important and/or interesting? What is the aim?
#
# It seems to me like we are trying to make the most general possible description of ??? algebra? A foundation to build on?
#
# ### Order (of an element)
#
#
#
#
# ### Permutation groups
#
#
#
#
# ### Symmetry groups
#
# Symmetry is a funny thing to measure as it depends on how you define it.
# Rubix cubes!!
#
#
# ### Groups of matricies
#
#
#
#
#
# ### Homomorphisms
#
# A function, f, is a homomorphism betweeen two groups iff $ f : G \rightarrow H $
#
#
# * So this could be used to help us find structural similarities (in the function, which is indeirectly related to the network topology) between neural networks.
#     * What sort nets would we expect to have similarities?
#     * What would a homomorphism between two NNs mean? Is it a feature?
#
# ### Isomorphism
#
# Homomorphism + bijection
#
#
#
# # Lets play
#
# I want to play with some groups and see what I can do with them. First, I need some groups. I want to try and pick some everyday groups (things you would find in the real world) that can be adequately abstracted into group theory. So, what properties do these 'everyday' objects need? ... ?
#
# What about;
#
#
# * a set of balls? Rugby, football, tennis, ... With the inflate/deflate operation. Well no.
#     * A inflated tennis ball does not equal a rugby ball, or a football, or anyother ball for that matter. So this group is not closed.
#
#
# * people eating at a resturaunt. Drunk crazy bitch (DB), policeman (PM), family man (FM), a well fed child (FC), angry resturaunt owner (AO), happy waitress (HW)... Where: $DB \circ AO = PM, DB \circ PM = HW, ...  $
#     * Probably not, because it suffers from a similar problem as the balls. Operations on the elements do not form a closed set (there is probably a more technical way of staing this). For example, $ AO \circ HW = ???$ (is this actually a problem, we could still go forward with the group?)
#     * There would be multipule mapping onto some elements and thus not so on others. Is this a requirement of groups? For example$FM \circ DB = DB \circ AO = PM $
#
#
# *

# %%
class Group():
    def __init__(self, elements, operator):
        self.elem = elements
        self.oper = operator
        
    def operate(a,b): 
        if a in self.elem and b in elem:
            c = self.oper(a,b)
            if c in self.elem:
                return c

# %% [markdown]
# # Questions
#
# * Where does the group store all the information about how the operation maps values onto itself? For example how does the group of integers with addition know that 2 + 2 = 4 and not 5.
# * Is it reasonable to view a group as a state machine? With a transition function mapping states to others? Or as a network where mappings are edges?
# * What if not all self-bijectional mappings are defined? Or they are not symmetric? Or not 1-1? Is that allowed?
# * Why is the operator only allowed to operate on two elements? If we dropped associativity as a requirement for groups we could make a more general structure? Where operators could act on different amunts of inputs and two inputs is just a special case.
