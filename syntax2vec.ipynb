# %%
import spacy
import torch

# %% [markdown]
# Current thought process is that we use word vectors because it doesnt seem sensible to learn word semantics/relations every time you train a new model.
#
# Does this logic also apply to synatx? (and positions?)
# Can we learn some part-of-speech embeddings?
# Given that there are so few parts-of-speech, can we just use onehot encodings? What do other embeddings by us? Can we learn them with the word encodings? How could this help?

# %%
nlp = spacy.load('en')
doc = nlp(u'They told us to duck.')
for word in doc:
    print(word.text, word.lemma, word.lemma_, word.tag, word.tag_, word.pos, word.pos_)
# Out:
# ...
#
#     Only loading the 'en' tokenizer.
#
# They 0  0  0
# told 0  0  0
# us 0  0  0
# to 0  0  0
# duck 0  0  0
# . 0  0  0

# %%
# !python -m spacy.en.download all
# Out:
# ...
#
#     The spacy.en.download command is now deprecated. Please use python -m
#     spacy download [model name or shortcut] instead. For more info and
#     available models, see the documentation: https://spacy.io/docs/usage.
# ...
#
#
# ...
#
# ...
#     16% |█████▍                          | 8.8MB 7.2kB/s eta 1:39:561Exception:
# Traceback (most recent call last):
#   File "/Volumes/ExtraDiskSpace/Documents/testing_word_encodings/venv/lib/python3.5/site-packages/pip/_vendor/requests/packages/urllib3/response.py", line 232, in _error_catcher
#     yield
#   File "/Volumes/ExtraDiskSpace/Documents/testing_word_encodings/venv/lib/python3.5/site-packages/pip/_vendor/requests/packages/urllib3/response.py", line 314, in read
#     data = self._fp.read(amt)
#   File "/usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py", line 433, in read
#     n = self.readinto(b)
# ...

# %%
# !pip install en_core_web_sm
# Out:
# ...
#   Could not find a version that satisfies the requirement en_core_web_sm (from versions: )
# No matching distribution found for en_core_web_sm

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#
# ...
# Exception:
# Traceback (most recent call last):
#   File "/Volumes/ExtraDiskSpace/Documents/testing_word_encodings/venv/lib/python3.5/site-packages/pip/_vendor/requests/packages/urllib3/response.py", line 232, in _error_catcher
#     yield
#   File "/Volumes/ExtraDiskSpace/Documents/testing_word_encodings/venv/lib/python3.5/site-packages/pip/_vendor/requests/packages/urllib3/response.py", line 314, in read
#     data = self._fp.read(amt)
#   File "/usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py", line 433, in read
#     n = self.readinto(b)
#   File "/usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/http/client.py", line 473, in readinto
#     n = self.fp.readinto(b)
#   File "/usr/local/Cellar/python3/3.5.1/Frameworks/Python.framework/Versions/3.5/lib/python3.5/socket.py", line 575, in readinto
#     return self._sock.recv_into(b)
# ...
