# %% [markdown]
# Problem: (according to david)
# * Totally random games are easy to model.
# * Adversarial games are easy to model.
# * Anything inbetween is not. (Slightly adversarial or cooperative)
#
# Wrong problem formulation??
#
# * Random
# * Maximisers/goal driven
#
# Thus an adversarial game is simply one where the players goals are opposing. Like a zero sum game??
#
# ### Definitions
#
# * A resource - something that helps a player achieve a goal.
#     * For example, actions, ??? so it is the set of available actions?
#     * If player A has a resource then it is their own.
#     * Another player, B, cannot interact with it (palyer A's resource), other than through using their (Player B's) resources.
# * A goal -
#
# So what happens when the set of avaiable actions is shared between two players?
#
# Do I think palyer B will
# I hope player B will do action X, but I cant be sure, so I will do it because I benefit. But, if player B thinks like me and has the same goal then ... ?
#
# ### Different goals, shared resources
#
# So instead lets imagine a scenario.
# A game with shared resources
# Each palyer has a goal, which is independent of ??
#
#
#
# If most of the resources are shared then there will be more competition and thus a more adversarial game (??)
# Similarly, less shared resources mean that each palyer is playing their own game.
#
# ### Different goals, different resources
#
# ... Not a game (??)
# Depends how you define it? Both players  are trying to win a game of chess
#
# ### Shared goals, shared resources
#
#
#
# ### Shared goals, different resources
#
# Imagine that we have two lazy students working on a project together.
# Their goal is get the best grade, but also, to individually do as little work as possible.
#
# Similar to the traditional game theory problems.
# Prisoners dilemma would fall under this?
# Minimax
# Alphabeta?
#
# * Two players playing chess, ...
#     * They share the goal of winning.
#         * As if one loses the other wins, thus they are both optimising for the same thing.
#     * Their resources to help them achieve their goal are each their own
