# %% [markdown]
# Just some notes from learning about category theory.
#
# ### Overview/thoughts
#
# It seems like category theory is a language of coeenctions. ??
#
#
# ### Monoids
#
# Is a group without the requirement of inverse elements.
# So a monoid is not closed?
#
# ### Categories
#
# Hmm, very abstract definition. It seems like a category can be anything that has objects and connections between those objects. Feels very similar to graph theory, with edges and verticies.
#
# > _Virtually every branch of modern mathematics can be described in terms of categories_
#
# Why is this such a nice abstraction? We see edges/verticies/nodes/links/weights/neurons/objects/morphisms/... coming up all the time. What is so natural about points and arrows?
#
# * it is a universal language (?)
# * easy to visualise/compare structure
#
#
# ##### Definition
#
# Let C be a category, then
#
# * obj(C) is the set of objects in C
# * hom(C) is the set of morphisms
# * composition
# * identity
# * associativity
#
# ##### Questions
#
# * Is it so general/abstract that it doesnt really tell us anything...? Or too powerful so that it can do everything and thus nothing. Like string theory? Or any suitably abstract and ambiguious idea/framework.
# * Do the morphisms need to be surjective,..,cts?
# * Hmm. So a category is not closed (?)
# * How is this different to a type? [Quora](https://www.quora.com/Whats-the-difference-between-category-theory-and-type-theory)
# * If we have the category Vec which has vector spaces as its objects linear maps as its morphisms. Then what is NonLinVec, the category with non-linear maps as its morphisms?
# *
#
# ### Morphisms
#
# Hmmm, this is interesing. An exploration of different types of morphism.
#
# > <i> A morphism f : a → b is called
# * a monomorphism (or monic) if fg1 = fg2 implies g1 = g2 for all morphisms g1, g2 : x → a.
# * an epimorphism (or epic) if g1f = g2f implies g1 = g2 for all morphisms g1, g2 : b → x.
# * a bimorphism if it is both a monomorphism and an epimorphism.
# * a retraction if it has a right inverse, i.e. if there exists a morphism g : b → a with fg = 1b.
# * a section if it has a left inverse, i.e. if there exists a morphism g : b → a with gf = 1a.
# * an isomorphism if it has an inverse, i.e. if there exists a morphism g : b → a with fg = 1b and gf = 1a.
# * an endomorphism if a = b. The class of endomorphisms of a is denoted end(a).
# * an automorphism if f is both an endomorphism and an isomorphism. The class of automorphisms of a is denoted aut(a). </i>
#
# It makes you wonder what different types of connection and objects there are.
#
# ### Monads
#
#
#
# ### Functors
#
# > _Functors can be thought of as homomorphisms between categories_
#
#
#
#
#
# ### Resources
#
# * http://www.cs.toronto.edu/~sme/presentations/cat101.pdf
# * http://yogsototh.github.io/Category-Theory-Presentation/#slide-38

# %% [markdown]
# # Questions
# * How is this realted to object oriented programming?
#     * [SE wisdom](http://stackoverflow.com/questions/2078978/functional-programming-vs-object-oriented-programming)
#     *
# * Monads?
# * Category/type theory?
# * What if you call a functional program back over itself. No like recursion, but like meta recursion? Foes this work?
#     * e.g. going back and forwards through the same recusrive algorithm?
# ```Haskell
# meta_recurse :: (a -> b) -> a -> b
# meta_recurse f x = r_func f $ reverse x
# meta_recurse f [] = []
# ```
#
#
#
# # Rescources
#
# * http://colah.github.io/posts/2015-09-NN-Types-FP/
# * https://github.com/EntilZha/PyFunctional
# * https://github.com/kachayev/fn.py
# * http://blog.sigfpe.com/2007/07/data-and-codata.html
#
# # Functors
# https://en.wikipedia.org/wiki/Higher-order_function
# http://mathoverflow.net/questions/103141/what-is-the-functor-tensor-product
#
# http://www.maths.ed.ac.uk/~aar/papers/maclanecat.pdf
# http://arxiv.org/pdf/1105.3104v4.pdf

# %% [markdown]
# > The main purpose of a type system is to reduce possibilities for bugs in computer programs
#
# > Type systems have other purposes as well, such as enabling certain compiler optimizations, allowing for multiple dispatch, providing a form of documentation, etc.
#
# > The hardware of a general purpose computer is unable to discriminate between for example a memory address and an instruction code, or between a character, an integer, or a floating-point number, because it makes no intrinsic distinction between any of the possible values that a sequence of bits might mean.[note 1] Associating a sequence of bits with a type conveys that meaning to the programmable hardware to form a symbolic system composed of that hardware and some program.
#
# > memory-safe language (or just safe language) to describe languages that do not allow programs to access memory that has not been assigned for their use
#
# * https://ncatlab.org/nlab/show/relation+between+type+theory+and+category+theory
# * http://plato.stanford.edu/entries/type-theory/
# * https://www.cs.princeton.edu/courses/archive/spring12/cos320/typing.pdf
# * http://www.jonmsterling.com/
# * http://typetheorypodcast.com/
