# %%
import tensorflow as tf
weights = tf.Variable(tf.zeros([784, 200]),name="weights")
biases = tf.Variable(tf.zeros([200,1]), name="biases")
saver = tf.train.Saver()

with tf.Session() as sess:
    saver.restore(sess, "/tmp/model.ckpt") #ok cool, so this over writes weights and biases defined before
    print("Model restored.")
    ans = sess.run(tf.matmul(weights,biases))
    print(ans)
# Out:
# Model restored.
# [[  6.05387807e-01]
#  [ -4.20167446e+00]
#  [ -5.70702744e+00]
#  [ -1.80610418e-02]
#  [  3.17662954e+00]
#  [ -2.64943743e+00]
#  [  2.83614230e+00]
#  [ -1.29642200e+00]
#  [  5.08376122e+00]
#  [  9.11314964e+00]
#  [  5.78637457e+00]
#  [  1.68950129e+00]
#  [  6.91360664e+00]
#  [  7.24527359e-01]
#  [  4.42126274e+00]
#  [ -3.95851946e+00]
#  [  1.00631466e+01]
#  [ -1.43135471e+01]
#  [ -6.53913379e-01]
#  [ -9.60356295e-02]
#  [  7.94725800e+00]
#  [  1.27931547e+00]
#  [ -7.79107380e+00]
#  [ -6.69676876e+00]
#  [ -4.83952999e+00]
#  [  3.75646472e+00]
#  [ -3.66618443e+00]
#  [  6.60179496e-01]
#  [ -8.05537462e-01]
#  [  1.51586938e+00]
#  [  4.26881981e+00]
#  [ -3.32814455e-01]
#  [ -3.85500526e+00]
#  [ -3.64961982e+00]
#  [  3.44902086e+00]
#  [ -1.46916866e+00]
#  [ -1.15886080e+00]
#  [ -1.22341263e+00]
#  [  3.33636093e+00]
#  [  2.56013155e+00]
#  [  1.90405512e+00]
#  [ -6.90242529e+00]
#  [ -1.91649377e+00]
#  [ -8.39131927e+00]
# ...
